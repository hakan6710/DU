# %% [markdown]
# # Data Understanding Template
#
# ## Ausfüllhinweise
# >In den einzelnen Punkten finden sich Ausfüllhinweise. Die können, genauso wie dieser Abschnitt, beim Beschreiben des Use Cases gelöscht werden.
#
# ## Use Case: <ID.Name>
# >Hier die eindeutige ID eintragen, z.B. UC_AP5.1.GKD.OberflächeninspektionAutomotive>

# %% [markdown]
# ## A) Sammlung der Daten /Auflistung der Datenquellen
# >In diesem Abschnitt sollen die Ergebnisse der Datenakquise dokumentiert werden
#
#
# >Diese Tabelle dient zur Auflistung der Datenquellen und der relevanten Aspekte, wie Speicherstrategie und Probleme.
#
# | **Name/ID für Quelle** | **Beschreibung** | **Methode/Strategie des Zugriffes** | **Speicherstrategie, Verfügbarkeit** |**IDs der gewonnenen Daten** |**Probleme**|
# |-------------|------------|----------|-----------------|-----------------|-----------------|
# |             |            |          |                 |                 |                 |
# |             |            |          |                 |                 |                 |
# |             |            |          |                 |                 |                 |

# %% [markdown]
# ### Weitere Probleme oder Anmerkungen

# %% [markdown]
# ## B) Beschreibung der Daten
# > Hier sollen die Datensätze gelistet und beschrieben werden
#
# | **Name/ID** | **Datentyp (syntaktisch)** | **Beschreibung (semantisch)** | **Domain Anmerkungen (units,  data ranges, volumes, codings,frequencies of data generation)** |
# |-------------|------------|----------|-----------------|
# |             |            |          |                 |
# |             |            |          |                 |
# |             |            |          |                 |

# %% [markdown]
# ## C) Erkundung der Daten
# > In diesem Abschnitt sollen die Ergebnisse der ersten Untersuchung der Daten dokumentiert werden. Dazu gehören unter anderem statistische Eigenschaften der Daten. Dabei sollen geeignete, prägnante Visualisierungen hier aufgelistet werden. Eine Einschätzung, ob die gesammelten für die Ziele ausreichen, soll aufgestellt werden
#
# ### Erkundungsergebnisse
#
#
# ### Optional: Wichtige Einflussgrößen und Zusammenhänge (“Critical to Quality”)
# > Hier werden alle Vermutungen beschrieben, welche Größen Einfluss auf den Prozess und die oben beschriebenen Ziele haben. Bitte angeben, ob die Einflüsse gemessen werden oder nicht.
#
# ### Optional: Eingriffsziele und -grenzen
# > Wenn am Ende des Projekts ein System in den Prozess eingreifen wird, werden hier die Zielfunktion (genau eine Zielfunktion!) und die erlaubten Grenzen von Eingriffen genannt. Bitte auch indirekte folgen der Eingriffe berücksichtigen. Aufgeführt werden manipulierbare Variablen, Zielfunktion und Schranken (technische Limits, Spezifikationsgrenzen)
#
# ### Zusammenfassung/ Einschätzung im Bezug auf die Ziele

# %% [markdown]
# ## D) Qualitätsuntersuchung der Daten
# >  Fragen die hier beantwortet werden sollen:
# >    - Vollständigkeit? Gibt es genug Daten zu allen Fällen?
# >    - Fehlerhafte Daten?
# >    - Fehlende Werte?
# >    - Korrelationen?

# %% [markdown]
#
#
# ### Beschreibung der Datenqualität für jeden Datentyp
#
#
#
# ### Bereinigungsstrategie
#
#
#
# ### Ergänzung/Ersatzstrategie
#
#
#
# ### Zusammenfassende Bewertung

# %% [markdown]
# # Beispiele:
#
# ## Excel Tabelle Einlesen

# %%
import pandas as pd
quellen_labels= ["ID", #
             "Desc", #
              "Zugr", #
              "Speicher", #
              "Ids",#
                "Prob"#
             ]
daten_labels= ["ID", #
             "Typ", #
              "Desc", #
              "Anmerkungen"#
             ]

df_quellen = pd.read_excel('DU-tables.xlsx', sheet_name='quellen',names=quellen_labels )
df_daten = pd.read_excel('DU-tables.xlsx', sheet_name='daten', names=daten_labels)
print("Schnittstellen: ")
print(df_quellen)
print("Daten: ")
print(df_daten)
# Out:
# Schnittstellen:
#          ID                 Desc       Zugr     Speicher    Ids Prob
# 0  Quelle 1  Test Beschreibung 1  Methode 1  Strategie 1  A,B,C   P1
# 1  Quelle 2  Test Beschreibung 2  Methode 2  Strategie 2  A,B,C   P2
# Daten:
#            ID     Typ                 Desc  Anmerkungen
# 0  Testname 1     int  Test Beschreibung 1  Anmerkung 1
# 1  Testname 2  double  Test Beschreibung 2  Anmerkung 2
# 2  Testname 3   float  Test Beschreibung 3  Anmerkung 3

# %% [markdown]
# ## Bilder einlesen
#
# ![Logo](pics/logo_MASKOR_rechts.png)
